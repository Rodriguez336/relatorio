# %%
# !pip install pandas

# %%
import pandas as pd

path = './Relatorio_2018.xlsx'

dados = pd.read_excel(path, sheet_name='Planilha1')

dados.head()
# Out:
#       Severidade            Inicio                  Temino              Name  \
# 0  Baixo Impacto  2023-06-26 19:38 2023-06-26 19:38:13.244    Fernanda Sousa
# 1  Baixo Impacto  2023-04-04 14:08 2023-04-04 14:08:02.230    Felipe  Moraes
# 2  Baixo Impacto  2023-05-04 13:08 2023-05-04 13:08:56.787     Robson Petrin
# 3  Baixo Impacto  2023-05-25 14:02 2023-05-25 14:02:41.754      Khelry Cunha
# 4  Baixo Impacto  2022-11-04 18:39 2022-11-04 18:39:58.961  Tatiane Oliveira
#
#                                      Usuario  Habilitado               Role  \
# 0              fernanda.sousa@alianzo.com.br        True            ;Master
# 1           felipe.moraes@tokiomarine.com.br        True        ;Technician
# 2                 Robson.Petrin@eldor.com.br        True     ;Master;Dossie
# 3                     khelry.cunha@lg.com.br        True            ;Master
# 4  ext.tatiane.oliveira@magazineluiza.com.br        True  ;Financial;Dossie
#
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Severidade  22 non-null     object
#  1   Inicio      22 non-null     object
#  2   Temino      22 non-null     datetime64[ns]
#  3   Name        22 non-null     object
#  4   Usuario     22 non-null     object
#  5   Habilitado  22 non-null     bool
#  6   Role        22 non-null     object
#  7   Ação        22 non-null     object
#  8   Menu        22 non-null     object
#  9   Descricao   22 non-null     object
#  10  Concluido   19 non-null     float64
#  11  Ano         22 non-null     int64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(8)
# memory usage: 2.0+ KB

# %%
dados.groupby('Role')['Usuario'].count()
# Out:
# Role
# ;Dossie                           1
# ;Financial;Dossie                 1
# ;HumanResources                   1
# ;Master                          15
# ;Master;Dossie                    1
# ;Master;HumanResources            1
# ;Master;HumanResources;Dossie     1
# ;Technician                       1
# Name: Usuario, dtype: int64

# %%
dados[dados['Usuario'].duplicated() == True]
# Out:
#        Severidade            Inicio                  Temino        Name  \
# 8   Baixo Impacto  2023-06-21 17:15 2023-06-21 17:15:43.235  Cristina -
# 16  Baixo Impacto  2023-05-29 17:39 2023-05-29 17:39:10.465     Osmar -
# 19  Baixo Impacto  2023-05-29 17:38 2023-05-29 17:38:33.435     Osmar -
# 21  Baixo Impacto  2023-05-18 12:53 2023-05-18 12:53:23.341     Osmar -
#
#                            Usuario  Habilitado     Role          Ação  \
# 8   cristina.facioli@skytef.com.br        True  ;Master  Visualização
# 16      osmar.neto@lusobank.com.br        True  ;Master      Download
# 19      osmar.neto@lusobank.com.br        True  ;Master      Download
# 21      osmar.neto@lusobank.com.br        True  ;Master      Download
#
#                           Menu  \
# 8           IV. Dossiê Digital
# 16  Gerenciamento de Documento
# 19  Gerenciamento de Documento
# 21  Gerenciamento de Documento
#
#                                             Descricao  Concluido   Ano
# ...

# %% [markdown]
# Relação usuario por Role 2018
#
# DOSSIE = 2
#
# FINANCIAL = 1
#
# HUMAN RESOURCES = 3
#
# MASTER = 18
#
# TECHNICIAN = 4
#
# Total de Usuarios = 22
# Total Roles = 28
